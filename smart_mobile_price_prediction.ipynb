# %% [raw]
# # This Python 3 environment comes with many helpful analytics libraries installed
# # It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# # For example, here's several helpful packages to load
#
# import numpy as np # linear algebra
# import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
#
# # Input data files are available in the read-only "../input/" directory
# # For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory
#
# import os
# for dirname, _, filenames in os.walk('/kaggle/input'):
#     for filename in filenames:
#         print(os.path.join(dirname, filename))
#
# # You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All"
# # You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import seaborn as sns
import matplotlib.pylab as plt
import numpy as np
import pandas as pd
# %matplotlib inline

df=pd.read_csv('/content/train.csv')
df.head(5)
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2  ...         20       756  2549     9     7         19
# 1        136        3  ...        905      1988  2631    17     3          7
# 2        145        5  ...       1263      1716  2603    11     2          9
# 3        131        6  ...       1216      1786  2769    16     8         11
# 4        141        2  ...       1208      1212  1411     8     2         15
#
#    three_g  touch_screen  wifi  price_range
# 0        0             0     1            1
# 1        1             1     0            2
# 2        1             1     0            2
# 3        1             0     0            2
# 4        1             1     0            1
#
# [5 rows x 21 columns]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   battery_power  2000 non-null   int64
#  1   blue           2000 non-null   int64
#  2   clock_speed    2000 non-null   float64
#  3   dual_sim       2000 non-null   int64
#  4   fc             2000 non-null   int64
#  5   four_g         2000 non-null   int64
#  6   int_memory     2000 non-null   int64
#  7   m_dep          2000 non-null   float64
#  8   mobile_wt      2000 non-null   int64
#  9   n_cores        2000 non-null   int64
#  10  pc             2000 non-null   int64
#  11  px_height      2000 non-null   int64
#  12  px_width       2000 non-null   int64
#  13  ram            2000 non-null   int64
#  14  sc_h           2000 non-null   int64
#  15  sc_w           2000 non-null   int64
#  16  talk_time      2000 non-null   int64
#  17  three_g        2000 non-null   int64
#  18  touch_screen   2000 non-null   int64
#  19  wifi           2000 non-null   int64
#  20  price_range    2000 non-null   int64
# dtypes: float64(2), int64(19)
# memory usage: 328.2 KB

# %%
tdf= df[df['sc_w'] != 0]
tdf.shape
# Out:
# (1820, 21)

# %%
sns.set()
price_plot=tdf['price_range'].value_counts().plot(kind='bar')
plt.xlabel('price_range')
plt.ylabel('Count')
plt.show()

# %%
tdf.iloc[:, :-1].describe().T.sort_values(by='std', ascending = False)\
                          .style.background_gradient(cmap="Greens")\
                          .bar(subset=["max"], color='#F8766D')\
                          .bar(subset=["mean"], color='#00BFC4')
# Out:
# <style type="text/css">
# #T_64b88_row0_col0, #T_64b88_row1_col0, #T_64b88_row1_col3, #T_64b88_row2_col0, #T_64b88_row3_col0, #T_64b88_row4_col0, #T_64b88_row5_col0, #T_64b88_row6_col0, #T_64b88_row6_col3, #T_64b88_row7_col0, #T_64b88_row8_col0, #T_64b88_row8_col2, #T_64b88_row8_col3, #T_64b88_row8_col4, #T_64b88_row8_col5, #T_64b88_row8_col6, #T_64b88_row9_col0, #T_64b88_row9_col2, #T_64b88_row10_col0, #T_64b88_row10_col2, #T_64b88_row10_col3, #T_64b88_row10_col4, #T_64b88_row10_col5, #T_64b88_row10_col6, #T_64b88_row11_col0, #T_64b88_row11_col2, #T_64b88_row11_col3, #T_64b88_row11_col4, #T_64b88_row11_col5, #T_64b88_row11_col6, #T_64b88_row12_col0, #T_64b88_row12_col2, #T_64b88_row12_col3, #T_64b88_row12_col4, #T_64b88_row12_col5, #T_64b88_row12_col6, #T_64b88_row13_col0, #T_64b88_row13_col2, #T_64b88_row13_col3, #T_64b88_row13_col4, #T_64b88_row13_col5, #T_64b88_row13_col6, #T_64b88_row14_col0, #T_64b88_row14_col2, #T_64b88_row14_col3, #T_64b88_row14_col4, #T_64b88_row14_col5, #T_64b88_row14_col6, #T_64b88_row15_col0, #T_64b88_row15_col2, #T_64b88_row15_col3, #T_64b88_row15_col4, #T_64b88_row15_col5, #T_64b88_row15_col6, #T_64b88_row16_col0, #T_64b88_row16_col2, #T_64b88_row16_col3, #T_64b88_row16_col4, #T_64b88_row16_col5, #T_64b88_row16_col6, #T_64b88_row17_col0, #T_64b88_row17_col2, #T_64b88_row17_col3, #T_64b88_row17_col4, #T_64b88_row17_col5, #T_64b88_row17_col6, #T_64b88_row18_col0, #T_64b88_row18_col2, #T_64b88_row18_col3, #T_64b88_row18_col4, #T_64b88_row18_col5, #T_64b88_row18_col6, #T_64b88_row19_col0, #T_64b88_row19_col2, #T_64b88_row19_col3, #T_64b88_row19_col4, #T_64b88_row19_col5, #T_64b88_row19_col6 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# #T_64b88_row0_col1 {
#   background-color: #00441b;
#   color: #f1f1f1;
#   width: 10em;
#   background: linear-gradient(90deg, #00BFC4 100.0%, transparent 100.0%);
# }
# #T_64b88_row0_col2, #T_64b88_row0_col4, #T_64b88_row0_col5, #T_64b88_row0_col6, #T_64b88_row2_col3, #T_64b88_row3_col3 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_64b88_row0_col3 {
#   background-color: #70c274;
#   color: #000000;
# }
# #T_64b88_row0_col7 {
#   background-color: #00441b;
#   color: #f1f1f1;
#   width: 10em;
#   background: linear-gradient(90deg, #F8766D 100.0%, transparent 100.0%);
# }
# #T_64b88_row1_col1 {
#   background-color: #b7e2b1;
#   color: #000000;
#   width: 10em;
#   background: linear-gradient(90deg, #00BFC4 30.3%, transparent 30.3%);
# }
# #T_64b88_row1_col2 {
#   background-color: #95d391;
#   color: #000000;
# }
# #T_64b88_row1_col4 {
#   background-color: #cbeac4;
#   color: #000000;
# }
# #T_64b88_row1_col5 {
#   background-color: #c4e8bd;
#   color: #000000;
# }
# #T_64b88_row1_col6 {
#   background-color: #b5e1ae;
#   color: #000000;
# }
# #T_64b88_row1_col7 {
#   background-color: #78c679;
#   color: #000000;
#   width: 10em;
#   background: linear-gradient(90deg, #F8766D 49.0%, transparent 49.0%);
# }
# #T_64b88_row2_col1 {
#   background-color: #53b466;
#   color: #f1f1f1;
#   width: 10em;
#   background: linear-gradient(90deg, #00BFC4 58.0%, transparent 58.0%);
# }
# #T_64b88_row2_col2 {
#   background-color: #97d492;
#   color: #000000;
# }
# #T_64b88_row2_col4 {
#   background-color: #2f974e;
#   color: #f1f1f1;
# }
# #T_64b88_row2_col5 {
#   background-color: #5ab769;
#   color: #f1f1f1;
# }
# #T_64b88_row2_col6 {
#   background-color: #6abf71;
#   color: #000000;
# }
# #T_64b88_row2_col7, #T_64b88_row3_col7 {
#   background-color: #75c477;
#   color: #000000;
#   width: 10em;
#   background: linear-gradient(90deg, #F8766D 50.0%, transparent 50.0%);
# }
# #T_64b88_row3_col1 {
#   background-color: #50b264;
#   color: #f1f1f1;
#   width: 10em;
#   background: linear-gradient(90deg, #00BFC4 58.7%, transparent 58.7%);
# }
# #T_64b88_row3_col2 {
#   background-color: #99d595;
#   color: #000000;
# }
# #T_64b88_row3_col4 {
#   background-color: #289049;
#   color: #f1f1f1;
# }
# #T_64b88_row3_col5 {
#   background-color: #55b567;
#   color: #f1f1f1;
# }
# #T_64b88_row3_col6 {
#   background-color: #66bd6f;
#   color: #f1f1f1;
# }
# #T_64b88_row4_col1 {
#   background-color: #eef8ea;
#   color: #000000;
#   width: 10em;
#   background: linear-gradient(90deg, #00BFC4 6.6%, transparent 6.6%);
# }
# #T_64b88_row4_col2 {
#   background-color: #f2faf0;
#   color: #000000;
# }
# #T_64b88_row4_col3 {
#   background-color: #ddf2d8;
#   color: #000000;
# }
# #T_64b88_row4_col4 {
#   background-color: #eaf7e6;
#   color: #000000;
# }
# #T_64b88_row4_col5 {
#   background-color: #eef8ea;
#   color: #000000;
# }
# #T_64b88_row4_col6 {
#   background-color: #eff9ec;
#   color: #000000;
# }
# #T_64b88_row4_col7 {
#   background-color: #f0f9ed;
#   color: #000000;
#   width: 10em;
#   background: linear-gradient(90deg, #F8766D 5.0%, transparent 5.0%);
# }
# #T_64b88_row5_col1 {
#   background-color: #f5fbf3;
#   color: #000000;
#   width: 10em;
#   background: linear-gradient(90deg, #00BFC4 1.5%, transparent 1.5%);
# }
# #T_64b88_row5_col2 {
#   background-color: #f5fbf2;
#   color: #000000;
# }
# #T_64b88_row5_col3, #T_64b88_row6_col2, #T_64b88_row6_col4, #T_64b88_row6_col5, #T_64b88_row6_col6, #T_64b88_row7_col2, #T_64b88_row7_col3, #T_64b88_row7_col4, #T_64b88_row7_col5, #T_64b88_row7_col6, #T_64b88_row9_col3, #T_64b88_row9_col4, #T_64b88_row9_col5, #T_64b88_row9_col6 {
#   background-color: #f6fcf4;
#   color: #000000;
# }
# #T_64b88_row5_col4, #T_64b88_row5_col5, #T_64b88_row5_col6 {
#   background-color: #f5fbf3;
#   color: #000000;
# }
# #T_64b88_row5_col7 {
#   background-color: #f5fbf2;
#   color: #000000;
#   width: 10em;
#   background: linear-gradient(90deg, #F8766D 1.6%, transparent 1.6%);
# }
# #T_64b88_row6_col1, #T_64b88_row7_col1 {
#   background-color: #f6fcf4;
#   color: #000000;
#   width: 10em;
#   background: linear-gradient(90deg, #00BFC4 0.5%, transparent 0.5%);
# }
# #T_64b88_row6_col7, #T_64b88_row7_col7, #T_64b88_row8_col7, #T_64b88_row9_col7, #T_64b88_row10_col7 {
#   background-color: #f6fcf4;
#   color: #000000;
#   width: 10em;
#   background: linear-gradient(90deg, #F8766D 0.5%, transparent 0.5%);
# }
# #T_64b88_row8_col1, #T_64b88_row11_col1 {
#   background-color: #f7fcf5;
#   color: #000000;
#   width: 10em;
#   background: linear-gradient(90deg, #00BFC4 0.2%, transparent 0.2%);
# }
# #T_64b88_row9_col1 {
#   background-color: #f6fcf4;
#   color: #000000;
#   width: 10em;
#   background: linear-gradient(90deg, #00BFC4 0.6%, transparent 0.6%);
# }
# #T_64b88_row10_col1 {
#   background-color: #f7fcf5;
#   color: #000000;
#   width: 10em;
#   background: linear-gradient(90deg, #00BFC4 0.3%, transparent 0.3%);
# }
# #T_64b88_row11_col7 {
#   background-color: #f7fcf5;
#   color: #000000;
#   width: 10em;
#   background: linear-gradient(90deg, #F8766D 0.2%, transparent 0.2%);
# }
# #T_64b88_row12_col1 {
#   background-color: #f7fcf5;
#   color: #000000;
#   width: 10em;
#   background: linear-gradient(90deg, #00BFC4 0.1%, transparent 0.1%);
# }
# #T_64b88_row12_col7 {
#   background-color: #f7fcf5;
#   color: #000000;
#   width: 10em;
#   background: linear-gradient(90deg, #F8766D 0.1%, transparent 0.1%);
# }
# #T_64b88_row13_col1, #T_64b88_row14_col1, #T_64b88_row15_col1, #T_64b88_row16_col1, #T_64b88_row17_col1, #T_64b88_row18_col1, #T_64b88_row19_col1 {
#   background-color: #f7fcf5;
#   color: #000000;
#   width: 10em;
#   background: linear-gradient(90deg, #00BFC4 0.0%, transparent 0.0%);
# }
# #T_64b88_row13_col7, #T_64b88_row14_col7, #T_64b88_row15_col7, #T_64b88_row16_col7, #T_64b88_row17_col7, #T_64b88_row18_col7, #T_64b88_row19_col7 {
#   background-color: #f7fcf5;
#   color: #000000;
#   width: 10em;
#   background: linear-gradient(90deg, #F8766D 0.0%, transparent 0.0%);
# }
# </style>
# <table id="T_64b88" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_64b88_level0_col0" class="col_heading level0 col0" >count</th>
#       <th id="T_64b88_level0_col1" class="col_heading level0 col1" >mean</th>
#       <th id="T_64b88_level0_col2" class="col_heading level0 col2" >std</th>
#       <th id="T_64b88_level0_col3" class="col_heading level0 col3" >min</th>
#       <th id="T_64b88_level0_col4" class="col_heading level0 col4" >25%</th>
#       <th id="T_64b88_level0_col5" class="col_heading level0 col5" >50%</th>
#       <th id="T_64b88_level0_col6" class="col_heading level0 col6" >75%</th>
#       <th id="T_64b88_level0_col7" class

# %%
# Number of uniqe elements in each columns
unique = tdf.nunique()
unique.to_frame().T
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0           1052     2           26         2  20       2          63     10
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        121        8  ...       1071      1056  1455    15    18         19
#
#    three_g  touch_screen  wifi  price_range
# 0        2             2     2            4
#
# [1 rows x 21 columns]

# %%
below= tdf["px_height"][tdf["px_height"] < 65]
n= len(below)
print("Number of values below 65 pixels in 'px_height' feature: ", n)
# Out:
# Number of values below 65 pixels in 'px_height' feature:  78

# %%
tdf.px_height.describe()
# Out:
# count    1820.000000
# mean      646.731319
# std       444.877537
# min         0.000000
# 25%       283.750000
# 50%       561.500000
# 75%       952.000000
# max      1960.000000
# Name: px_height, dtype: float64

# %%
sns.set(rc={'figure.figsize':(5,5)})
ax=sns.displot(data=tdf["m_dep"])
plt.show()

# %%
X=tdf.drop(['price_range'], axis=1)
y=tdf['price_range']
#missing values
X.isna().any()
# Out:
# battery_power    False
# blue             False
# clock_speed      False
# dual_sim         False
# fc               False
# four_g           False
# int_memory       False
# m_dep            False
# mobile_wt        False
# n_cores          False
# pc               False
# px_height        False
# px_width         False
# ram              False
# sc_h             False
# sc_w             False
# talk_time        False
# three_g          False
# touch_screen     False
# wifi             False
# dtype: bool

# %%
plt.figure(figsize=(22,4))
sns.heatmap((tdf.isna().sum()).to_frame(name='').T,cmap='GnBu', annot=True,
             fmt='0.0f').set_title('Count missing values (train data)', fontsize=18)
plt.show()

# %%
#Exploratory Data Analysis (EDA)
T= 'price_range'
F= [col for col in tdf.columns if col not in ['tdf', T]]

cat_features = [col for col in F if tdf[col].nunique() < 25]
cont_features = [col for col in F if tdf[col].nunique() >= 25]

num_cat_features = len(cat_features)
num_cont_features = len(cont_features)

print(f"Total number of features except for the target: {len(FEATURES)}")
print(f"\033[92mNumber of categorical (<25 Unique Values) features: {num_cat_Features}")
print(f"\033[96mNumber of continuous features: {num_cont_features}")

# Define labels and colors for the pie chart
labels = ['Categorical (<25 Unique Values)', 'Continuous']
colors = ['#bbddcb', '#cdddbb']

plt.pie([num_cat_features, num_cont_features],
        labels=labels,
        colors=colors,
        textprops={'fontsize': 13},
        autopct='%1.1f%%')

# Add a title to the plot
plt.title('Distribution of Categorical and Continuous Features', fontsize=16)

# Show the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-44-510361466867> in <cell line: 11>()
#       9 num_cont_features = len(cont_features)
#      10
# ---> 11 print(f"Total number of features except for the target: {len(FEATURES)}")
#      12 print(f"\033Number of categorical (<25 Unique Values) features: {num_cat_features}")
#      13 print(f"\033Number of continuous features: {num_cont_features}")
#
# NameError: name 'FEATURES' is not defined

# %%
#check for data balance
value_counts= pd.value_counts(tdf['price_range'])

# Define the label strings using f-strings
label = [f'{"Very high" if i==0 else "High" if i==1 else "Medium" if i==2 else "Low"} cost' for i in range(len(value_counts))]

# Define the colors for each pie slice
colors = ['#4d9b68', '#538e8a', '#468e71', '#59ae8c']

# Create a pie chart with percentage values formatted with a % sign and explode the slices
fig, ax = plt.subplots()
ax.pie(value_counts.values, autopct='%0.1f%%', explode=[0.1, 0.1, 0.1, 0.1], shadow=True, labels=label, colors=colors)

# Set the title of the pie chart
ax.set_title('Balanced or Imbalanced?')

# Show the pie chart
plt.show()

# %%
#building random forest model
from sklearn.ensemble import RandomForestClassifier
rfc=RandomForestClassifier(bootstrap= True,
                           max_depth= 7,
                           max_features= 15,
                           min_samples_leaf= 3,
                           min_samples_split= 10,
                           n_estimators= 200,
                           random_state=7)

# %%
#train test split of data
from sklearn.model_selection import train_test_split
X_train, X_valid, y_train, y_valid= train_test_split(X, y, test_size=0.2, random_state=7)

# %%
#confusion matrix
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
def my_confusion_matrix(y_test, y_pred, plt_title):
    cm=confusion_matrix(y_test, y_pred)
    print(classification_report(y_test, y_pred))
    sns.heatmap(cm, annot=True, fmt='g', cbar=False, cmap='Greens')
    plt.xlabel('Predicted Values')
    plt.ylabel('Actual Values')
    plt.title(plt_title)
    plt.show()
    return cm

# %%
#using raandom forest model to our train and test data
rfc.fit(X_train, y_train)
y_pred_rfc=rfc.predict(X_valid)

# %%
print('Random Forest Classifier Accuracy Score: ',accuracy_score(y_valid,y_pred_rfc))
cm_rfc=my_confusion_matrix(y_valid, y_pred_rfc, 'Random Forest Confusion Matrix')

# %%
# using Guassian Naive Bayes model
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
gnb.fit(X_train, y_train)
y_pred_gnb=gnb.predict(X_valid)

# %%
print('Gaussian NB Classifier Accuracy Score: ',accuracy_score(y_valid,y_pred_gnb))
cm_rfc=my_confusion_matrix(y_valid, y_pred_gnb, 'Gaussian NB Confusion Matrix')

# %%
#using KNN classifier
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=3,leaf_size=25)
knn.fit(X_train, y_train)
y_pred_knn=knn.predict(X_valid)
print('KNN Classifier Accuracy Score: ',accuracy_score(y_valid,y_pred_knn))
cm_rfc=my_confusion_matrix(y_valid, y_pred_knn, 'KNN Confusion Matrix')

# %%
#using SVM classifier
from sklearn import svm
svm_clf = svm.SVC(decision_function_shape='ovo')
svm_clf.fit(X_train, y_train)
y_pred_svm=svm_clf.predict(X_valid)
print('SVM Classifier Accuracy Score: ',accuracy_score(y_valid,y_pred_svm))
cm_rfc=my_confusion_matrix(y_valid, y_pred_svm, 'SVM Confusion Matrix')
